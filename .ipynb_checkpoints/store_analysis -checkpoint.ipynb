# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
mpl.rcParams['axes.unicode_minus'] = False
# %matplotlib inline

# %%
from matplotlib import font_manager, rc
# font_path = "C:/Windows/Fonts/D2Coding-Ver1.3.2-20180524.ttc"
font_path = "./NanumGothic.ttf"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
pascucci_read = pd.read_csv('./caffe_pascucci.csv')
pascucci_read
# Out:
#      Unnamed: 0         store  sido  gugun  \
# 0             0          서대문역    서울   서대문구
# 1             1          김포DT   경기도    김포시
# 2             2  경기광주휴게소 서울방향   경기도    광주시
# 3             3          대전문지    대전    유성구
# 4             4         서청주DT  충청북도    청주시
# ..          ...           ...   ...    ...
# 528         528         인천논현점    인천    남동구
# 529         529          광안리점    부산    수영구
# 530         530        테크노마트점    서울    광진구
# 531         531        목포 하당점  전라남도    목포시
# 532         532         광주수완점    광주  광주광역시
#
#                                            address
# 0                      서울시 서대문구 충정로 60 KT&G; 빌딩 1층
# 1                                 경기 김포시 김포대로 1135
# 2                              경기 광주시 곤지암읍 만삼로 211
# 3                           대전 유성구 문지로 299번길 86-11
# 4                           충북 청주시 흥덕구 2순환로 1067-2
# ..                                             ...
# 528                          인천광역시 남동구 논현동 627-5번지
# 529                  부산시 수영구 민락동 179-2   파스쿠찌 광안리점
# 530  서울시 광진구 구의동 546-4 테크노마트 지하 D-10호  파스쿠찌 테크노마트점
# 531                     전남 목포시 상동 889번지 파스쿠찌 목포하당점
# 532                          전남 광주광역시 광산구 장덕동 1661
#
# [533 rows x 5 columns]

# %%
starbucks_read = pd.read_csv('./starbucks.csv')
starbucks_read
# Out:
#       Unnamed: 0        store     sido  gugun  \
# 0              0    역삼아레나빌딩      서울특별시    강남구
# 1              1     논현역사거리      서울특별시    강남구
# 2              2    신사역성일빌딩      서울특별시    강남구
# 3              3     국기원사거리      서울특별시    강남구
# 4              4     스탈릿대치R      서울특별시    강남구
# ...          ...          ...      ...    ...
# 1609        1609      세종이마트    세종특별자치시    금송로
# 1610        1610       세종청사    세종특별자치시   도움8로
# 1611        1611       세종아름    세종특별자치시  아름서1길
# 1612        1612       세종소담    세종특별자치시   소담3로
# 1613        1613  세종충남대학교병원    세종특별자치시   보듬7로
#
#                                                 address
# 0                      서울특별시 강남구 언주로 425 (역삼동)1522-3232
# 1                     서울특별시 강남구 강남대로 538 (논현동)1522-3232
# 2                     서울특별시 강남구 강남대로 584 (논현동)1522-3232
# 3                     서울특별시 강남구 테헤란로 125 (역삼동)1522-3232
# 4                   서울특별시 강남구 남부순환로 2947 (대치동)1522-3232
# ...                                                 ...
# 1609          세종특별자치시 금송로 687(가람동 406) 이마트 세종점1522-3232
# 1610                    세종특별자치시  도움8로 81 (어진동)1522-3232
# 1611  세종특별자치시 아름서1길 13-9 (아름동) 103,104,105,202,203호1...
# 1612  세종특별자치시 소담3로 8 (소담동) 1동  12호,13호,14호,15호,15a호,...
# 1613           세종특별자치시 보듬7로 20 (도담동) 헬스케어센터 1층1522-3232
#
# [1614 rows x 5 columns]

# %%
starbucks_sido_index = ['서울특별시', '경기도', '광주광역시', '대구광역시', '부산광역시', '울산광역시', '인천광역시', '강원도', '경상남도', '경상북도', '전라남도', '전라북도', '충청남도', '충청북도','제주특별자치도', '세종특별자치시']
pascucci_sido_index = ['서울', '경기도', '광주', '대구', '부산', '울산', '인천', '강원도', '경상남도', '경상북도', '전라남도', '전라북도', '충청남도', '충청북도', '제주도', '세종시특별자치시']

# %%
starbucks_서울 = starbucks_read[starbucks_read['sido'] == starbucks_sido_index[0]]
starbucks_서울
# Out:
#      Unnamed: 0      store   sido gugun  \
# 0             0  역삼아레나빌딩    서울특별시   강남구
# 1             1   논현역사거리    서울특별시   강남구
# 2             2  신사역성일빌딩    서울특별시   강남구
# 3             3   국기원사거리    서울특별시   강남구
# 4             4   스탈릿대치R    서울특별시   강남구
# ..          ...        ...    ...   ...
# 562         562     사가정역    서울특별시   중랑구
# 563         563      상봉역    서울특별시   중랑구
# 564         564    묵동이마트    서울특별시   중랑구
# 565         565       묵동    서울특별시   중랑구
# 566         566      중화역    서울특별시   중랑구
#
#                                                address
# 0                     서울특별시 강남구 언주로 425 (역삼동)1522-3232
# 1                    서울특별시 강남구 강남대로 538 (논현동)1522-3232
# 2                    서울특별시 강남구 강남대로 584 (논현동)1522-3232
# 3                    서울특별시 강남구 테헤란로 125 (역삼동)1522-3232
# 4                  서울특별시 강남구 남부순환로 2947 (대치동)1522-3232
# ..                                                 ...
# 562                         서울특별시 중랑구 면목로 3101522-3232
# 563                   서울특별시 중랑구 망우로 307 (상봉동)1522-3232
# 564  서울특별시 중랑구 동일로 932 (묵동, 묵동자이아파트) (묵동이마트 B1층)152...
# 565                        서울특별시 중랑구 동일로 952 1522-3232
# 566                    서울특별시 중랑구 봉화산로 35 1,2층1522-3232
#
# [565 rows x 5 columns]

# %%
pascucci_서울 = pascucci_read[pascucci_read['sido'] == pascucci_sido_index[0]]
pascucci_서울
# Out:
#      Unnamed: 0    store sido gugun  \
# 0             0     서대문역   서울  서대문구
# 14           14    영등포병원   서울  영등포구
# 19           19     신금호역   서울   성동구
# 29           29    천호로데오   서울   강동구
# 33           33    용산삼각지   서울   용산구
# ..          ...      ...  ...   ...
# 511         511  목동파리공원점   서울   양천구
# 513         513   서초효령로점   서울   서초구
# 522         522   서울대병원점   서울   종로구
# 523         523   포스코센터점   서울   강남구
# 530         530   테크노마트점   서울   광진구
#
#                                                address
# 0                          서울시 서대문구 충정로 60 KT&G; 빌딩 1층
# 14                                  서울 영등포구 당산로 31길 10
# 19                               서울 성동구 무수막길 95 솔베이그빌딩
# 29                                서울시 강동구 구천면로 212, 1층
# 33   서울 용산구 한강로2가 426 용산트리스퀘어 101동 104호, 105호(용산구 백...
# ..                                                 ...
# 511                         서울시 양천구 목동 907-10번지 현대파리지앙
# 513                                 서울시 서초구 서초동 1487-4
# 522                 서울시 종로구 대학로 101 서울대학교병원 본관 1F 파스쿠찌
# 523           서울 강남구 대치동 891-43 앰에스에이빌딩 1F 파스쿠찌 포스코센터점
# 530      서울시 광진구 구의동 546-4 테크노마트 지하 D-10호  파스쿠찌 테크노마트점
#
# [69 rows x 5 columns]

# %%
print(len(starbucks_서울))
print(len(pascucci_서울))
# Out:
# 565
# 69

# %%
서울_list = []
서울_list.append([len(starbucks_서울)] + [len(pascucci_서울)])
data = pd.DataFrame(서울_list, columns = ['starbucks','pascucci'], index = ['서울'])
data
# Out:
#     starbucks  pascucci
# 서울        565        69

# %%
plt.rcParams["figure.figsize"] = (8, 6)
plt.rcParams['axes.grid'] = True
plt.rc('font', size=15) 

data_bar = data.plot.bar(color=['g','r'], width=0.3)
plt.show()

# %%
sido_list = []
for i in range(len(pascucci_sido_index)):
    starbucks = starbucks_read[starbucks_read['sido'] == starbucks_sido_index[i]]
    pascucci = pascucci_read[pascucci_read['sido'] == pascucci_sido_index[i]]
    sido_list.append([len(starbucks)] + [len(pascucci)])
sido_data = pd.DataFrame(sido_list, columns = ['starbucks','pascucci'], index = pascucci_sido_index)
sido_data
# Out:
#           starbucks  pascucci
# 서울              565        69
# 경기도             366        81
# 광주               59        28
# 대구               70        46
# 부산              127        29
# 울산               30        29
# 인천               63        29
# 강원도              25        14
# 경상남도             60        28
# 경상북도             47        33
# 전라남도             23        31
# 전라북도             27        15
# 충청남도             34        19
# 충청북도             25        28
# 제주도              23        22
# 세종시특별자치시         11         6

# %%
plt.rcParams["figure.figsize"] = (16, 10)
plt.rcParams['axes.grid'] = True
plt.rc('font', size=15) 


sido_data_bar = sido_data.plot.bar(color=['g','r'], width=0.8)


plt.show()
